# %%
# %%HTML
# <style>
#    div#notebook-container    { width: 95%; }
#    div#menubar-container     { width: 65%; }
#    div#maintoolbar-container { width: 99%; }
# </style>
# Out:
# <style>
#    div#notebook-container    { width: 95%; }
#    div#menubar-container     { width: 65%; }
#    div#maintoolbar-container { width: 99%; }
# </style>

# %%
import numpy as np
import pandas as pd
import os
import time
import datetime
import json
import copy
import gc
import warnings
from tqdm import tqdm_notebook, tqdm

import optuna

import lightgbm as lgb
import xgboost as xgb

from catboost import CatBoostRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold,TimeSeriesSplit, GroupKFold
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.svm import NuSVR, SVR
from sklearn.metrics import mean_absolute_error
from sklearn import preprocessing

import eli5
from eli5.sklearn import PermutationImportance

import networkx as nx

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
folder_path =  '../data/IEEE-CIS-Fraud-Detection/'
os.listdir(folder_path)
# Out:
# ['test_identity.csv',
#  'ieee-gb-2-make-amount-useful-again_train.pkl',
#  'merge_two_csv.ipynb',
#  'test_identity.csv.zip',
#  'lgb-single-model-lb-0-9419_test.pkl',
#  'extensive-eda-and-modeling-xgb-hyperopt_train.pkl',
#  'test.csv',
#  'day-and-time-powerful-predictive-feature_test.pkl',
#  'eda-and-models_test.pkl',
#  'train_identity_fixed.pkl',
#  'test_transaction_fixed.pkl',
#  'almost-complete-feature-engineering-ieee-data_train.pkl',
#  'almost-complete-feature-engineering-ieee-data_test.pkl',
#  'test_identity.pkl',
#  'train_transaction.pkl',
#  'sample_submission.csv',
#  'train_transaction.csv',
#  'train_transaction.csv.zip',
#  'extensive-eda-and-modeling-xgb-hyperopt_test.pkl',
#  'feature-engineering-lightgbm_test.pkl',
#  'fraud-complete-eda_train.pkl',
#  'test_transaction.csv',
#  'feature-engineering-lightgbm_train.pkl',
#  'sample_submission.csv.zip',
#  'test_identity_fixed.pkl',
#  'lgb-single-model-lb-0-9419_train.pkl',
#  '.DS_Store',
#  'train_identity.csv.zip',
#  'df_train.gzde',
#  'train_identity.pkl',
#  'train_transaction_fixed.pkl',
#  '.ipynb_checkpoints',
#  'day-and-time-powerful-predictive-feature_train.pkl',
#  'train_identity.csv',
#  'df_test.gzde',
#  'eda-and-models_train.pkl',
#  'test_transaction.pkl',
#  'fraud-complete-eda_test.pkl',
#  'train.csv',
#  'ieee-gb-2-make-amount-useful-again_test.pkl',
#  'test_transaction.csv.zip']

# %%
feature_pkl_list = [pkl for pkl in os.listdir(folder_path) if pkl.endswith('train.pkl') or pkl.endswith('test.pkl')]
print(len(feature_pkl_list))
print(feature_pkl_list)
# Out:
# 16
# ['ieee-gb-2-make-amount-useful-again_train.pkl', 'lgb-single-model-lb-0-9419_test.pkl', 'extensive-eda-and-modeling-xgb-hyperopt_train.pkl', 'day-and-time-powerful-predictive-feature_test.pkl', 'eda-and-models_test.pkl', 'almost-complete-feature-engineering-ieee-data_train.pkl', 'almost-complete-feature-engineering-ieee-data_test.pkl', 'extensive-eda-and-modeling-xgb-hyperopt_test.pkl', 'feature-engineering-lightgbm_test.pkl', 'fraud-complete-eda_train.pkl', 'feature-engineering-lightgbm_train.pkl', 'lgb-single-model-lb-0-9419_train.pkl', 'day-and-time-powerful-predictive-feature_train.pkl', 'eda-and-models_train.pkl', 'fraud-complete-eda_test.pkl', 'ieee-gb-2-make-amount-useful-again_test.pkl']

# %%
csv_list = ['train_transaction.csv', 'test_transaction.csv', 'train_identity.csv', 'test_identity.csv']
print(len(csv_list))
print(csv_list)
# Out:
# 4
# ['train_transaction.csv', 'test_transaction.csv', 'train_identity.csv', 'test_identity.csv']

# %%
def prepare_basic_feature(folder_path, csv_list):
    df = pd.read_csv(f'{folder_path}{csv_list[0]}')
    for file in csv_list[1:]:
        df = pd.merge(df, pd.read_csv(f'{folder_path}{file}'), how='left', on='TransactionID')
    return df.sort_values(by=['TransactionID']).reset_index(drop=True)

# %%
# df_train, df_test = prepare_basic_feature(file_folder, csv_list)
# print('basic feature size')
# print(df_train.shape, df_test.shape)

# for f in feature_pkl_list:
#     print(f'========================={f}===============================')
#     if (f.endswith('.pkl')) and (not f.startswith('.')):
#         if f[:-4].endswith('train'):
#             df_feature_i = pd.read_pickle(f'{file_folder}/{f}', compression='gzip').sort_values(by=['TransactionID'])
#             df_feature_i = df_feature_i.reset_index(drop=True)
#             columns_i = df_feature_i.columns.tolist()
#             new_columns = set(columns_i) - set(df_train.columns.tolist())
#             duplicates_columns = [col for col in columns_i if col not in list(new_columns)]
#             duplicates_columns_diff_values = []
#             for col in duplicates_columns:
#                 try:
#                     error = np.where(df_feature_i[col].values!=df_train[col].values)[0]
#                     if error.shape[0] > 0:
#                         duplicates_columns_diff_values.append(col)
#                 except Exception as e:
#                     raise Exception(e.__str__())
# #                     pass
#             df_train = pd.merge(df_train, df_feature_i[list(new_columns) + ['TransactionID']], on='TransactionID')
#             rename_col = {}
#             for col in duplicates_columns_diff_values:
#                 rename_col[col] = f'{f[:-4]}_{col}'
#             df_train = pd.merge(df_train, df_feature_i[list(duplicates_columns_diff_values) + ['TransactionID']].rename(columns=rename_col), on='TransactionID')
#             df_train = df_train.sort_values(by=['TransactionID'])
#             df_train = df_train.reset_index(drop=True)
#             print('train add', f, new_columns)
            
            
#         if f[:-4].endswith('test'):
#             df_feature_i = pd.read_pickle(f'{file_folder}/{f}', compression='gzip').sort_values(by=['TransactionID'])
#             df_feature_i = df_feature_i.reset_index(drop=True)
#             columns_i = df_feature_i.columns.tolist()
#             new_columns = set(columns_i) - set(df_test.columns.tolist())
#             duplicates_columns = [col for col in columns_i if col not in list(new_columns)]
#             duplicates_columns_diff_values = []
#             for col in duplicates_columns:
#                 try:
#                     error = np.where(df_feature_i[col].values!=df_test[col].values)[0]
#                     if error.shape[0] > 0:
#                         duplicates_columns_diff_values.append(col)
#                 except Exception as e:
#                     raise Exception(e.__str__())
# #                     pass
#             df_test = pd.merge(df_test, df_feature_i[list(new_columns) + ['TransactionID']], on='TransactionID')
#             rename_col = {}
#             for col in duplicates_columns_diff_values:
#                 rename_col[col] = f'{f[:-4]}_{col}'
#             df_test = pd.merge(df_test, df_feature_i[list(duplicates_columns_diff_values) + ['TransactionID']].rename(columns=rename_col), on='TransactionID')
#             df_test = df_test.sort_values(by=['TransactionID'])
#             df_test = df_test.reset_index(drop=True)
#             print('test add', f, new_columns)

# %%
def prepare_data(folder_path, feature_pkl_list, csv_list, prepare_basic_feature):
    
    df = prepare_basic_feature(folder_path, csv_list)
    print('basic feature size')
    print(df.shape)

    for f in feature_pkl_list:
        print(f'========================={f}===============================')
        if (f.endswith('.pkl')) and (not f.startswith('.')):
            if (f[:-4].endswith('train')) or (f[:-4].endswith('test')):
                df_feature_i = pd.read_pickle(f'{folder_path}/{f}', compression='gzip').sort_values(by=['TransactionID'])
                df_feature_i = df_feature_i.reset_index(drop=True)
                columns_i = df_feature_i.columns.tolist()
                new_columns = set(columns_i) - set(df.columns.tolist())
                duplicates_columns = [col for col in columns_i if col not in list(new_columns)]
                duplicates_columns_diff_values = []
                for col in duplicates_columns:
                    try:
                        error = np.where(df_feature_i[col].values!=df[col].values)[0]
                        if error.shape[0] > 0:
                            duplicates_columns_diff_values.append(col)
                    except Exception as e:
                        raise Exception(e.__str__())
    #                     pass
                df = pd.merge(df, df_feature_i[list(new_columns) + ['TransactionID']], on='TransactionID')
                rename_col = {}
                for col in duplicates_columns_diff_values:
                    rename_col[col] = f'{f[:-4]}_{col}'
                print('rename_col', len(rename_col))
#                 df = pd.merge(df, df_feature_i[list(duplicates_columns_diff_values) + ['TransactionID']].rename(columns=rename_col), on='TransactionID')
                df = df.sort_values(by=['TransactionID'])
                df = df.reset_index(drop=True)
                print('df add', f, new_columns)
    
#     print(f'=========================save tmp===============================')
#     df_train.to_pickle(f'{folder_path}/df_train.gzde', compression='gzip')
#     df_test.to_pickle(f'{folder_path}/df_test.gzde', compression='gzip')
    return df

# %%
folder_path, feature_pkl_list, csv_list
# Out:
# ('../data/IEEE-CIS-Fraud-Detection/',
#  ['ieee-gb-2-make-amount-useful-again_train.pkl',
#   'lgb-single-model-lb-0-9419_test.pkl',
#   'extensive-eda-and-modeling-xgb-hyperopt_train.pkl',
#   'day-and-time-powerful-predictive-feature_test.pkl',
#   'eda-and-models_test.pkl',
#   'almost-complete-feature-engineering-ieee-data_train.pkl',
#   'almost-complete-feature-engineering-ieee-data_test.pkl',
#   'extensive-eda-and-modeling-xgb-hyperopt_test.pkl',
#   'feature-engineering-lightgbm_test.pkl',
#   'fraud-complete-eda_train.pkl',
#   'feature-engineering-lightgbm_train.pkl',
#   'lgb-single-model-lb-0-9419_train.pkl',
#   'day-and-time-powerful-predictive-feature_train.pkl',
#   'eda-and-models_train.pkl',
#   'fraud-complete-eda_test.pkl',
#   'ieee-gb-2-make-amount-useful-again_test.pkl'],
#  ['train_transaction.csv',
#   'test_transaction.csv',
#   'train_identity.csv',
#   'test_identity.csv'])

# %%
[pkl for pkl in feature_pkl_list if 'train' in pkl],[csv for csv in csv_list if 'train' in csv]
# Out:
# (['ieee-gb-2-make-amount-useful-again_train.pkl',
#   'extensive-eda-and-modeling-xgb-hyperopt_train.pkl',
#   'almost-complete-feature-engineering-ieee-data_train.pkl',
#   'fraud-complete-eda_train.pkl',
#   'feature-engineering-lightgbm_train.pkl',
#   'lgb-single-model-lb-0-9419_train.pkl',
#   'day-and-time-powerful-predictive-feature_train.pkl',
#   'eda-and-models_train.pkl'],
#  ['train_transaction.csv', 'train_identity.csv'])

# %%
df_train = prepare_data(folder_path, [pkl for pkl in feature_pkl_list if 'train' in pkl], [csv for csv in csv_list if 'train' in csv], prepare_basic_feature)
# Out:
# basic feature size
# (590540, 434)
# =========================ieee-gb-2-make-amount-useful-again_train.pkl===============================
# rename_col 402
# df add ieee-gb-2-make-amount-useful-again_train.pkl {'card1_TransactionAmt_mean', 'card2_fq_enc', 'TransactionAmt_check', 'DT_day', 'C11_fq_enc', 'uid3_fq_enc', 'D7_fq_enc', 'id_30_fq_enc', 'D2_fq_enc', 'id_33_1', 'dist1_fq_enc', 'C13_fq_enc', 'id_31_device_fq_enc', 'C3_fq_enc', 'id_31_device', 'uid2_TransactionAmt_std', 'M_sum', 'uid', 'C9_fq_enc', 'R_emaildomain_prefix', 'uid3', 'C10_fq_enc', 'D1_fq_enc', 'D3_fq_enc', 'ProductCD_target_mean', 'D6_fq_enc', 'C12_fq_enc', 'id_33_0', 'R_emaildomain_fq_enc', 'card3_TransactionAmt_std', 'C6_fq_enc', 'C14_fq_enc', 'card5_TransactionAmt_std', 'dist2_fq_enc', 'card5_TransactionAmt_mean', 'DeviceInfo_device_fq_enc', 'DT_day_week', 'addr1_fq_enc', 'id_30_version_fq_enc', 'card2_TransactionAmt_mean', 'card1_fq_enc', 'uid_TransactionAmt_mean', 'P_emaildomain_prefix', 'P_emaildomain_fq_enc', 'card3_TransactionAmt_mean', 'uid2_TransactionAmt_mean', 'id_30_device_fq_enc', 'uid3_TransactionAmt_std', 'DT_hour', 'C1_fq_enc', 'DeviceInfo_version', 'C8_fq_enc', 'C2_fq_enc', 'card3_fq_enc', 'email_check', 'D8_fq_enc', 'C4_fq_enc', 'C7_fq_enc', 'id_30_version', 'D5_fq_enc', 'card5_fq_enc', 'uid_fq_enc', 'card2_TransactionAmt_std', 'uid2_fq_enc', 'id_30_device', 'uid_TransactionAmt_std', 'DeviceInfo_device', 'TransactionAmt_log1p', 'addr2_fq_enc', 'M4_target_mean', 'DeviceInfo_version_fq_enc', 'uid2', 'M_na', 'id_33_fq_enc', 'card1_TransactionAmt_std', 'DeviceInfo_fq_enc', 'C5_fq_enc', 'uid3_TransactionAmt_mean'}
# =========================extensive-eda-and-modeling-xgb-hyperopt_train.pkl===============================
# rename_col 82
# df add extensive-eda-and-modeling-xgb-hyperopt_train.pkl {'P_emaildomain_suffix', 'TransactionAmt_to_mean_card1', 'TransactionAmt_to_std_card1', 'R_emaildomain_suffix', 'P_emaildomain_bin', 'R_emaildomain_bin'}
# =========================almost-complete-feature-engineering-ieee-data_train.pkl===============================
# rename_col 22
# df add almost-complete-feature-engineering-ieee-data_train.pkl {'PCA_V_28', 'count_cluster', 'PCA_D_3', 'PCA_D_2', 'PCA_C_2', 'PCA_D_5', 'TransactionAmt_to_mean_card_id', 'max_last', '_Hours', 'PCA_D_4', 'PCA_D_6', 'PCA_D_7', 'clusters_C', '_Weekdays', 'min_last', 'PCA_D_0', '_Days', 'Card_ID', 'TransactionAmt_to_std_card_id', 'PCA_D_1', 'first_value_card1', 'clusters_D', 'std_last', 'PCA_C_0', 'mean_last', 'PCA_C_1', '_Minutes', 'first_value_addr1', '_Second'}
# =========================fraud-complete-eda_train.pkl===============================
# rename_col 401
# df add fraud-complete-eda_train.pkl set()
# =========================feature-engineering-lightgbm_train.pkl===============================
# rename_col 258
# df add feature-engineering-lightgbm_train.pkl {'card5_count_full', 'card2_count_full', 'D15_to_std_card1', 'id_02__D8', 'card2__dist1', 'screen_height', 'TransactionAmt_Log', 'id_02_to_std_card4', 'id_36_count_full', 'browser_id_31', 'TransactionAmt_decimal', 'OS_id_30', 'id_02_to_mean_card4', 'card6_count_full', 'card5__P_emaildomain', 'D15_to_mean_addr1', 'card4_count_full', 'Transaction_day_of_week', 'card2__id_20', 'device_version', 'version_id_30', 'D15_to_mean_card1', 'id_02_to_mean_card1', 'P_emaildomain__C2', 'had_id', 'DeviceInfo__P_emaildomain', 'id_02_to_mean_addr1', 'id_02__id_20', 'screen_width', 'card1__card5', 'card1_count_full', 'card3_count_full', 'id_02_to_std_card1', 'D15_to_std_addr1', 'device_name', 'Transaction_hour', 'addr1__card1', 'id_02_to_std_addr1'}
# =========================lgb-single-model-lb-0-9419_train.pkl===============================
# rename_col 245
# df add lgb-single-model-lb-0-9419_train.pkl set()
# =========================day-and-time-powerful-predictive-feature_train.pkl===============================
# rename_col 0
# df add day-and-time-powerful-predictive-feature_train.pkl {'make_hour_feature', 'make_day_feature'}
# =========================eda-and-models_train.pkl===============================
# rename_col 318
# df add eda-and-models_train.pkl {'R_emaildomain_2', 'P_emaildomain_1', 'P_emaildomain_2', 'R_emaildomain_1'}

# %%
for col in df_train.columns:
    print(col, df_train[col].dtype)
# Out:
# TransactionID int64
# isFraud int64
# TransactionDT int64
# TransactionAmt float64
# ProductCD object
# card1 int64
# card2 float64
# card3 float64
# card4 object
# card5 float64
# card6 object
# addr1 float64
# addr2 float64
# dist1 float64
# dist2 float64
# P_emaildomain object
# R_emaildomain object
# C1 float64
# C2 float64
# C3 float64
# C4 float64
# C5 float64
# C6 float64
# C7 float64
# C8 float64
# C9 float64
# C10 float64
# C11 float64
# C12 float64
# C13 float64
# C14 float64
# D1 float64
# D2 float64
# D3 float64
# D4 float64
# D5 float64
# D6 float64
# D7 float64
# D8 float64
# D9 float64
# D10 float64
# D11 float64
# D12 float64
# D13 float64
# D14 float64
# D15 float64
# M1 object
# M2 object
# M3 object
# M4 object
# M5 object
# M6 object
# M7 object
# M8 object
# M9 object
# V1 float64
# V2 float64
# V3 float64
# V4 float64
# V5 float64
# V6 float64
# V7 float64
# V8 float64
# V9 float64
# V10 float64
# V11 float64
# V12 float64
# V13 float64
# V14 float64
# V15 float64
# V16 float64
# V17 float64
# V18 float64
# V19 float64
# V20 float64
# V21 float64
# V22 float64
# V23 float64
# V24 float64
# V25 float64
# V26 float64
# V27 float64
# V28 float64
# V29 float64
# V30 float64
# V31 float64
# V249 float64
# V250 float64
# V251 float64
# V252 float64
# V253 float64
# V254 float64
# V255 float64
# V256 float64
# V257 float64
# V258 float64
# V259 float64
# V260 float64
# V261 float64
# V262 float64
# V263 float64
# V264 float64
# V265 float64
# V266 float64
# V267 float64
# V268 float64
# V269 float64
# V270 float64
# V271 float64
# V272 float64
# V273 float64
# V274 float64
# V275 float64
# V276 float64
# V277 float64
# V278 float64
# V279 float64
# V280 float64
# V281 float64
# V282 float64
# V283 float64
# V284 float64
# V285 float64
# V286 float64
# V287 float64
# V288 float64
# V289 float64
# V290 float64
# V291 float64
# V292 float64
# V293 float64
# V294 float64
# V295 float64
# V296 float64
# V297 float64
# V298 float64
# V299 float64
# V300 float64
# V301 float64
# V302 float64
# V303 float64
# V304 float64
# V305 float64
# V306 float64
# V307 float64
# V308 float64
# V309 float64
# V310 float64
# V311 float64
# V312 float64
# V313 float64
# V314 float64
# V315 float64
# V316 float64
# V317 float64
# V318 float64
# V319 float64
# V320 float64
# V321 float64
# V322 float64
# V323 float64
# V324 float64
# V325 float64
# V326 float64
# V327 float64
# V328 float64
# V329 float64
# V330 float64
# V331 float64
# V332 float64
# V333 float64
# V334 float64
# V335 float64
# V336 float64
# V337 float64
# V338 float64
# V339 float64
# id_01 float64
# id_02 float64
# id_03 float64
# id_04 float64
# id_05 float64
# id_06 float64
# id_07 float64
# id_08 float64
# id_09 float64
# id_10 float64
# id_11 float64
# id_12 object
# id_13 float64
# id_14 float64
# id_15 object
# id_16 object
# id_17 float64
# id_18 float64
# id_19 float64
# id_20 float64
# id_21 float64
# id_22 float64
# id_23 object
# id_24 float64
# id_25 float64
# id_26 float64
# id_27 object
# id_28 object
# id_29 object
# id_30 object
# id_31 object
# id_32 float64
# id_33 object
# id_34 object
# id_35 object
# id_36 object
# id_37 object
# id_38 object
# DeviceType object
# DeviceInfo object
# card1_TransactionAmt_mean float64
# card2_fq_enc int64
# TransactionAmt_check int64
# DT_day int64
# C11_fq_enc int64
# uid3_fq_enc int64
# D7_fq_enc int64
# id_30_fq_enc int64
# D2_fq_enc int64
# id_33_1 float64
# dist1_fq_enc int64
# C13_fq_enc int64
# id_31_device_fq_enc int64
# C3_fq_enc int64
# id_31_device int64
# uid2_TransactionAmt_std float64
# M_sum int64
# uid int64
# C9_fq_enc int64
# R_emaildomain_prefix int64
# uid3 int64
# C10_fq_enc int64
# D1_fq_enc int64
# D3_fq_enc int64
# ProductCD_target_mean float64
# D6_fq_enc int64
# C12_fq_enc int64
# id_33_0 float64
# R_emaildomain_fq_enc int64
# card3_TransactionAmt_std float64
# C6_fq_enc int64
# C14_fq_enc int64
# card5_TransactionAmt_std float64
# dist2_fq_enc int64
# card5_TransactionAmt_mean float64
# DeviceInfo_device_fq_enc int64
# DT_day_week int64
# addr1_fq_enc int64
# id_30_version_fq_enc int64
# card2_TransactionAmt_mean float64
# card1_fq_enc int64
# uid_TransactionAmt_mean float64
# P_emaildomain_prefix int64
# P_emaildomain_fq_enc int64
# card3_TransactionAmt_mean float64
# uid2_TransactionAmt_mean float64
# id_30_device_fq_enc int64
# uid3_TransactionAmt_std float64
# DT_hour int64
# C1_fq_enc int64
# DeviceInfo_version int64
# C8_fq_enc int64
# C2_fq_enc int64
# card3_fq_enc int64
# email_check int64
# D8_fq_enc int64
# C4_fq_enc int64
# C7_fq_enc int64
# id_30_version int64
# D5_fq_enc int64
# card5_fq_enc int64
# uid_fq_enc int64
# card2_TransactionAmt_std float64
# uid2_fq_enc int64
# id_30_device int64
# uid_TransactionAmt_std float64
# DeviceInfo_device int64
# TransactionAmt_log1p float16
# addr2_fq_enc int64
# M4_target_mean float64
# DeviceInfo_version_fq_enc int64
# uid2 int64
# M_na int64
# id_33_fq_enc int64
# card1_TransactionAmt_std float64
# DeviceInfo_fq_enc int64
# C5_fq_enc int64
# uid3_TransactionAmt_mean float64
# P_emaildomain_suffix int64
# TransactionAmt_to_mean_card1 float16
# TransactionAmt_to_std_card1 float64
# R_emaildomain_suffix int64
# P_emaildomain_bin int64
# R_emaildomain_bin int64
# PCA_V_28 float16
# count_cluster int64
# PCA_D_3 float16
# PCA_D_2 float16
# PCA_C_2 float16
# PCA_D_5 float16
# TransactionAmt_to_mean_card_id float16
# max_last float16
# _Hours int64
# PCA_D_4 float16
# PCA_D_6 float16
# PCA_D_7 float16
# clusters_C int64
# _Weekdays int64
# min_last float16
# PCA_D_0 float16
# _Days int64
# Card_ID int64
# TransactionAmt_to_std_card_id float16
# PCA_D_1 float16
# first_value_card1 float16
# clusters_D int64
# std_last float16
# PCA_C_0 float16
# mean_last float16
# PCA_C_1 float16
# _Minutes int64
# first_value_addr1 float16
# _Second int64
# card5_count_full int64
# card2_count_full int64
# D15_to_std_card1 float64
# id_02__D8 int64
# card2__dist1 int64
# screen_height int64
# TransactionAmt_Log float16
# id_02_to_std_card4 float16
# id_36_count_full int64
# browser_id_31 int64
# TransactionAmt_decimal int64
# OS_id_30 int64
# id_02_to_mean_card4 float16
# card6_count_full int64
# card5__P_emaildomain int64
# D15_to_mean_addr1 float16
# card4_count_full int64
# Transaction_day_of_week float16
# card2__id_20 int64
# device_version int64
# version_id_30 int64
# D15_to_mean_card1 float16
# id_02_to_mean_card1 float16
# P_emaildomain__C2 int64
# had_id float16
# DeviceInfo__P_emaildomain int64
# id_02_to_mean_addr1 float16
# id_02__id_20 int64
# screen_width int64
# card1__card5 int64
# card1_count_full int64
# card3_count_full int64
# id_02_to_std_card1 float64
# D15_to_std_addr1 float64
# device_name int64
# Transaction_hour float16
# addr1__card1 int64
# id_02_to_std_addr1 float16
# make_hour_feature float64
# make_day_feature float64
# R_emaildomain_2 int64
# P_emaildomain_1 int64
# P_emaildomain_2 int64
# R_emaildomain_1 int64

# %%
# df_train.to_pickle(f'{folder_path}/df_train.gzde', compression='gzip')
# del df_train

# %%
df_test = prepare_data(folder_path, [pkl for pkl in feature_pkl_list if 'test' in pkl], [csv for csv in csv_list if 'test' in csv], prepare_basic_feature)
# Out:
# basic feature size
# (506691, 433)
# =========================lgb-single-model-lb-0-9419_test.pkl===============================
# rename_col 248
# df add lgb-single-model-lb-0-9419_test.pkl {'P_emaildomain__C2', 'card1_count_full', 'id_36_count_full', 'TransactionAmt_decimal', 'DeviceInfo__P_emaildomain', 'id_02__D8', 'Transaction_hour', 'addr1__card1', 'card2__dist1', 'card5__P_emaildomain', 'id_02__id_20', 'Transaction_day_of_week', 'card2__id_20', 'card1__card5'}
# =========================day-and-time-powerful-predictive-feature_test.pkl===============================
# rename_col 0
# df add day-and-time-powerful-predictive-feature_test.pkl {'make_hour_feature', 'make_day_feature'}
# =========================eda-and-models_test.pkl===============================
# rename_col 313
# df add eda-and-models_test.pkl {'TransactionAmt_to_mean_card1', 'R_emaildomain_1', 'D15_to_std_card1', 'TransactionAmt_to_std_card1', 'id_02_to_std_card1', 'D15_to_std_addr1', 'id_02_to_mean_card4', 'P_emaildomain_2', 'R_emaildomain_2', 'D15_to_mean_addr1', 'id_02_to_std_card4', 'P_emaildomain_1', 'D15_to_mean_card1', 'id_02_to_mean_card1'}
# =========================almost-complete-feature-engineering-ieee-data_test.pkl===============================
# rename_col 20
# df add almost-complete-feature-engineering-ieee-data_test.pkl {'PCA_V_28', 'count_cluster', 'PCA_D_3', 'PCA_D_2', 'PCA_C_2', 'R_emaildomain_bin', 'PCA_D_5', 'TransactionAmt_to_mean_card_id', 'max_last', '_Hours', 'PCA_D_4', 'PCA_D_6', 'PCA_D_7', 'clusters_C', '_Weekdays', 'min_last', 'PCA_D_0', '_Days', 'R_emaildomain_suffix', 'Card_ID', 'TransactionAmt_to_std_card_id', 'PCA_D_1', 'first_value_card1', 'clusters_D', 'std_last', 'P_emaildomain_bin', 'PCA_C_0', 'mean_last', 'PCA_C_1', '_Minutes', 'P_emaildomain_suffix', 'first_value_addr1', '_Second'}
# =========================extensive-eda-and-modeling-xgb-hyperopt_test.pkl===============================
# rename_col 92
# df add extensive-eda-and-modeling-xgb-hyperopt_test.pkl set()
# =========================feature-engineering-lightgbm_test.pkl===============================
# rename_col 265
# df add feature-engineering-lightgbm_test.pkl {'had_id', 'card5_count_full', 'browser_id_31', 'card3_count_full', 'OS_id_30', 'card2_count_full', 'device_name', 'id_02_to_mean_addr1', 'id_02_to_std_addr1', 'card6_count_full', 'screen_height', 'TransactionAmt_Log', 'card4_count_full', 'screen_width', 'device_version', 'version_id_30'}
# =========================fraud-complete-eda_test.pkl===============================
# rename_col 374
# df add fraud-complete-eda_test.pkl set()
# =========================ieee-gb-2-make-amount-useful-again_test.pkl===============================
# rename_col 375
# df add ieee-gb-2-make-amount-useful-again_test.pkl {'card1_TransactionAmt_mean', 'card2_fq_enc', 'TransactionAmt_check', 'DT_day', 'C11_fq_enc', 'uid3_fq_enc', 'D7_fq_enc', 'id_30_fq_enc', 'D2_fq_enc', 'id_33_1', 'dist1_fq_enc', 'C13_fq_enc', 'id_31_device_fq_enc', 'C3_fq_enc', 'id_31_device', 'uid2_TransactionAmt_std', 'M_sum', 'uid', 'C9_fq_enc', 'R_emaildomain_prefix', 'uid3', 'C10_fq_enc', 'D1_fq_enc', 'D3_fq_enc', 'ProductCD_target_mean', 'D6_fq_enc', 'C12_fq_enc', 'id_33_0', 'R_emaildomain_fq_enc', 'card3_TransactionAmt_std', 'C6_fq_enc', 'C14_fq_enc', 'card5_TransactionAmt_std', 'dist2_fq_enc', 'card5_TransactionAmt_mean', 'DeviceInfo_device_fq_enc', 'DT_day_week', 'addr1_fq_enc', 'id_30_version_fq_enc', 'card2_TransactionAmt_mean', 'card1_fq_enc', 'uid_TransactionAmt_mean', 'P_emaildomain_prefix', 'P_emaildomain_fq_enc', 'card3_TransactionAmt_mean', 'uid2_TransactionAmt_mean', 'id_30_device_fq_enc', 'uid3_TransactionAmt_std', 'DT_hour', 'C1_fq_enc', 'DeviceInfo_version', 'C8_fq_enc', 'C2_fq_enc', 'card3_fq_enc', 'email_check', 'D8_fq_enc', 'C4_fq_enc', 'C7_fq_enc', 'id_30_version', 'D5_fq_enc', 'card5_fq_enc', 'uid_fq_enc', 'card2_TransactionAmt_std', 'uid2_fq_enc', 'id_30_device', 'uid_TransactionAmt_std', 'DeviceInfo_device', 'TransactionAmt_log1p', 'addr2_fq_enc', 'M4_target_mean', 'DeviceInfo_version_fq_enc', 'uid2', 'M_na', 'id_33_fq_enc', 'card1_TransactionAmt_std', 'DeviceInfo_fq_enc', 'C5_fq_enc', 'uid3_TransactionAmt_mean'}

# %%
for col in df_test.columns:
    print(col, df_test[col].dtype)
# Out:
# TransactionID int64
# TransactionDT int64
# TransactionAmt float64
# ProductCD object
# card1 int64
# card2 float64
# card3 float64
# card4 object
# card5 float64
# card6 object
# addr1 float64
# addr2 float64
# dist1 float64
# dist2 float64
# P_emaildomain object
# R_emaildomain object
# C1 float64
# C2 float64
# C3 float64
# C4 float64
# C5 float64
# C6 float64
# C7 float64
# C8 float64
# C9 float64
# C10 float64
# C11 float64
# C12 float64
# C13 float64
# C14 float64
# D1 float64
# D2 float64
# D3 float64
# D4 float64
# D5 float64
# D6 float64
# D7 float64
# D8 float64
# D9 float64
# D10 float64
# D11 float64
# D12 float64
# D13 float64
# D14 float64
# D15 float64
# M1 object
# M2 object
# M3 object
# M4 object
# M5 object
# M6 object
# M7 object
# M8 object
# M9 object
# V1 float64
# V2 float64
# V3 float64
# V4 float64
# V5 float64
# V6 float64
# V7 float64
# V8 float64
# V9 float64
# V10 float64
# V11 float64
# V12 float64
# V13 float64
# V14 float64
# V15 float64
# V16 float64
# V17 float64
# V18 float64
# V19 float64
# V20 float64
# V21 float64
# V22 float64
# V23 float64
# V24 float64
# V25 float64
# V26 float64
# V27 float64
# V28 float64
# V29 float64
# V30 float64
# V31 float64
# V32 float64
# V33 float64
# V34 float64
# V35 float64
# V36 float64
# V37 float64
# V38 float64
# V39 float64
# V40 float64
# V41 float64
# V42 float64
# V43 float64
# V44 float64
# V45 float64
# V46 float64
# V47 float64
# V48 float64
# V49 float64
# V50 float64
# V51 float64
# V52 float64
# V271 float64
# V272 float64
# V273 float64
# V274 float64
# V275 float64
# V276 float64
# V277 float64
# V278 float64
# V279 float64
# V280 float64
# V281 float64
# V282 float64
# V283 float64
# V284 float64
# V285 float64
# V286 float64
# V287 float64
# V288 float64
# V289 float64
# V290 float64
# V291 float64
# V292 float64
# V293 float64
# V294 float64
# V295 float64
# V296 float64
# V297 float64
# V298 float64
# V299 float64
# V300 float64
# V301 float64
# V302 float64
# V303 float64
# V304 float64
# V305 float64
# V306 float64
# V307 float64
# V308 float64
# V309 float64
# V310 float64
# V311 float64
# V312 float64
# V313 float64
# V314 float64
# V315 float64
# V316 float64
# V317 float64
# V318 float64
# V319 float64
# V320 float64
# V321 float64
# V322 float64
# V323 float64
# V324 float64
# V325 float64
# V326 float64
# V327 float64
# V328 float64
# V329 float64
# V330 float64
# V331 float64
# V332 float64
# V333 float64
# V334 float64
# V335 float64
# V336 float64
# V337 float64
# V338 float64
# V339 float64
# id_01 float64
# id_02 float64
# id_03 float64
# id_04 float64
# id_05 float64
# id_06 float64
# id_07 float64
# id_08 float64
# id_09 float64
# id_10 float64
# id_11 float64
# id_12 object
# id_13 float64
# id_14 float64
# id_15 object
# id_16 object
# id_17 float64
# id_18 float64
# id_19 float64
# id_20 float64
# id_21 float64
# id_22 float64
# id_23 object
# id_24 float64
# id_25 float64
# id_26 float64
# id_27 object
# id_28 object
# id_29 object
# id_30 object
# id_31 object
# id_32 float64
# id_33 object
# id_34 object
# id_35 object
# id_36 object
# id_37 object
# id_38 object
# DeviceType object
# DeviceInfo object
# P_emaildomain__C2 int64
# card1_count_full int64
# id_36_count_full int64
# TransactionAmt_decimal int64
# DeviceInfo__P_emaildomain int64
# id_02__D8 int64
# Transaction_hour float64
# addr1__card1 int64
# card2__dist1 int64
# card5__P_emaildomain int64
# id_02__id_20 int64
# Transaction_day_of_week float64
# card2__id_20 int64
# card1__card5 int64
# make_hour_feature float64
# make_day_feature float64
# TransactionAmt_to_mean_card1 float64
# R_emaildomain_1 int64
# D15_to_std_card1 float64
# TransactionAmt_to_std_card1 float64
# id_02_to_std_card1 float64
# D15_to_std_addr1 float64
# id_02_to_mean_card4 float64
# P_emaildomain_2 int64
# R_emaildomain_2 int64
# D15_to_mean_addr1 float64
# id_02_to_std_card4 float64
# P_emaildomain_1 int64
# D15_to_mean_card1 float64
# id_02_to_mean_card1 float64
# PCA_V_28 float16
# count_cluster int64
# PCA_D_3 float16
# PCA_D_2 float16
# PCA_C_2 float16
# R_emaildomain_bin int64
# PCA_D_5 float16
# TransactionAmt_to_mean_card_id float16
# max_last float16
# _Hours int64
# PCA_D_4 float16
# PCA_D_6 float16
# PCA_D_7 float16
# clusters_C int64
# _Weekdays int64
# min_last float16
# PCA_D_0 float16
# _Days int64
# R_emaildomain_suffix int64
# Card_ID int64
# TransactionAmt_to_std_card_id float16
# PCA_D_1 float16
# first_value_card1 float16
# clusters_D int64
# std_last float16
# P_emaildomain_bin int64
# PCA_C_0 float16
# mean_last float16
# PCA_C_1 float16
# _Minutes int64
# P_emaildomain_suffix int64
# first_value_addr1 float16
# _Second int64
# had_id float16
# card5_count_full int64
# browser_id_31 int64
# card3_count_full int64
# OS_id_30 int64
# card2_count_full int64
# device_name int64
# id_02_to_mean_addr1 float16
# id_02_to_std_addr1 float16
# card6_count_full int64
# screen_height int64
# TransactionAmt_Log float16
# card4_count_full int64
# screen_width int64
# device_version int64
# version_id_30 int64
# card1_TransactionAmt_mean float64
# card2_fq_enc int64
# TransactionAmt_check int64
# DT_day int64
# C11_fq_enc int64
# uid3_fq_enc int64
# D7_fq_enc int64
# id_30_fq_enc int64
# D2_fq_enc int64
# id_33_1 float64
# dist1_fq_enc int64
# C13_fq_enc int64
# id_31_device_fq_enc int64
# C3_fq_enc int64
# id_31_device int64
# uid2_TransactionAmt_std float64
# M_sum int64
# uid int64
# C9_fq_enc int64
# R_emaildomain_prefix int64
# uid3 int64
# C10_fq_enc int64
# D1_fq_enc int64
# D3_fq_enc int64
# ProductCD_target_mean float64
# D6_fq_enc int64
# C12_fq_enc int64
# id_33_0 float64
# R_emaildomain_fq_enc int64
# card3_TransactionAmt_std float64
# C6_fq_enc int64
# C14_fq_enc int64
# card5_TransactionAmt_std float64
# dist2_fq_enc int64
# card5_TransactionAmt_mean float64
# DeviceInfo_device_fq_enc int64
# DT_day_week int64
# addr1_fq_enc int64
# id_30_version_fq_enc int64
# card2_TransactionAmt_mean float64
# card1_fq_enc int64
# uid_TransactionAmt_mean float64
# P_emaildomain_prefix int64
# P_emaildomain_fq_enc int64
# card3_TransactionAmt_mean float64
# uid2_TransactionAmt_mean float64
# id_30_device_fq_enc int64
# uid3_TransactionAmt_std float64
# DT_hour int64
# C1_fq_enc int64
# DeviceInfo_version int64
# C8_fq_enc int64
# C2_fq_enc int64
# card3_fq_enc int64
# email_check int64
# D8_fq_enc int64
# C4_fq_enc int64
# C7_fq_enc int64
# id_30_version int64
# D5_fq_enc int64
# card5_fq_enc int64
# uid_fq_enc int64
# card2_TransactionAmt_std float64
# uid2_fq_enc int64
# id_30_device int64
# uid_TransactionAmt_std float64
# DeviceInfo_device int64
# TransactionAmt_log1p float16
# addr2_fq_enc int64
# M4_target_mean float64
# DeviceInfo_version_fq_enc int64
# uid2 int64
# M_na int64
# id_33_fq_enc int64
# card1_TransactionAmt_std float64
# DeviceInfo_fq_enc int64
# C5_fq_enc int64
# uid3_TransactionAmt_mean float64

# %%
# df_test.to_pickle(f'{folder_path}/df_test.gzde', compression='gzip')
# del df_test

# %%
df_train = pd.read_pickle(f'{folder_path}/df_train.gzde', compression='gzip')
df_test = pd.read_pickle(f'{folder_path}/df_test.gzde', compression='gzip')

# %%
df_train.shape
# Out:
# (590540, 591)

# %%
import sys
sys.path.append("..") # Adds higher directory to python modules path.
from kaggleKID.preprocessing import check_dataframe

df_train2, df_test2, diff_type_cols, not_numbic_cols, na_existed_cols, all_na_cols, trn_tst_imbalance_col = check_dataframe(df_train, df_test,['TransactionID','TransactionDT'])
# Out:
# train Transaction_hour is float16 and test Transaction_hour is float64
# train Transaction_day_of_week is float16 and test Transaction_day_of_week is float64
# train id_02_to_std_card4 is float16 and test id_02_to_std_card4 is float64
# train TransactionAmt_to_mean_card1 is float16 and test TransactionAmt_to_mean_card1 is float64
# train D15_to_mean_card1 is float16 and test D15_to_mean_card1 is float64
# train D15_to_mean_addr1 is float16 and test D15_to_mean_addr1 is float64
# train id_02_to_mean_card4 is float16 and test id_02_to_mean_card4 is float64
# train id_02_to_mean_card1 is float16 and test id_02_to_mean_card1 is float64
# ProductCD object
# card4 object
# card6 object
# P_emaildomain object
# R_emaildomain object
# M1 object
# M2 object
# M3 object
# M4 object
# M5 object
# M6 object
# M7 object
# M8 object
# M9 object
# id_12 object
# id_15 object
# id_16 object
# id_23 object
# id_27 object
# id_28 object
# id_29 object
# id_30 object
# id_31 object
# id_33 object
# id_34 object
# id_35 object
# id_36 object
# id_37 object
# id_38 object
# DeviceType object
# DeviceInfo object
# transfer ProductCD
# transfer card4
# transfer card6
# transfer P_emaildomain
# transfer R_emaildomain
# transfer M1
# transfer M2
# transfer M3
# transfer M4
# transfer M5
# transfer M6
# transfer M7
# transfer M8
# transfer M9
# transfer id_12
# transfer id_15
# transfer id_16
# transfer id_23
# transfer id_27
# transfer id_28
# transfer id_29
# transfer id_30
# transfer id_31
# transfer id_33
# transfer id_34
# transfer id_35
# transfer id_36
# transfer id_37
# transfer id_38
# transfer DeviceType
# transfer DeviceInfo
# card2 8933 8654 float64 [100.0, 100.0] [600.0, 600.0]
# card3 1565 3002 float64 [100.0, 100.0] [231.0, 232.0]
# card5 4259 4547 float64 [100.0, 100.0] [237.0, 237.0]
# addr1 65706 65609 float64 [100.0, 100.0] [540.0, 540.0]
# addr2 65706 65609 float64 [10.0, 10.0] [102.0, 102.0]
# dist1 352271 291217 float64 [0.0, 0.0] [10286.0, 8081.0]
# dist2 552913 470255 float64 [0.0, 0.0] [11623.0, 9213.0]
# C1 0 3 float64 [0.0, 0.0] [4685.0, 2950.0]
# C2 0 3 float64 [0.0, 0.0] [5691.0, 3275.0]
# C3 0 3 float64 [0.0, 0.0] [26.0, 31.0]
# C4 0 3 float64 [0.0, 0.0] [2253.0, 1601.0]
# C5 0 3 float64 [0.0, 0.0] [349.0, 376.0]
# C6 0 3 float64 [0.0, 0.0] [2253.0, 1601.0]
# C7 0 3 float64 [0.0, 0.0] [2255.0, 1621.0]
# C8 0 3 float64 [0.0, 0.0] [3331.0, 1005.0]
# C9 0 3 float64 [0.0, 0.0] [210.0, 572.0]
# C10 0 3 float64 [0.0, 0.0] [3257.0, 881.0]
# C11 0 3 float64 [0.0, 0.0] [3188.0, 2234.0]
# C12 0 3 float64 [0.0, 0.0] [3188.0, 2234.0]
# C13 0 4748 float64 [0.0, 0.0] [2918.0, 1562.0]
# C14 0 3 float64 [0.0, 0.0] [1429.0, 797.0]
# D1 1269 6031 float64 [0.0, 0.0] [640.0, 641.0]
# D2 280797 234769 float64 [0.0, 0.0] [640.0, 641.0]
# id_05 453675 371941 float64 [-72.0, -81.0] [52.0, 52.0]
# id_06 453675 371941 float64 [-100.0, -100.0] [0.0, 0.0]
# id_07 585385 501632 float64 [-46.0, -41.0] [61.0, 59.0]
# id_08 585385 501632 float64 [-100.0, -100.0] [0.0, 0.0]
# id_09 515614 432353 float64 [-36.0, -32.0] [25.0, 16.0]
# id_10 515614 432353 float64 [-100.0, -100.0] [0.0, 0.0]
# id_11 449562 369913 float64 [90.0, 90.0] [100.0, 100.0]
# id_13 463220 376405 float64 [10.0, 11.0] [64.0, 63.0]
# id_14 510496 435334 float64 [-660.0, -720.0] [720.0, 720.0]
# id_17 451171 370725 float64 [100.0, 100.0] [229.0, 228.0]
# id_18 545427 455816 float64 [10.0, 11.0] [29.0, 29.0]
# id_19 451222 370785 float64 [100.0, 100.0] [671.0, 670.0]
# id_20 451279 371058 float64 [100.0, 100.0] [661.0, 660.0]
# id_21 585381 501632 float64 [100.0, 100.0] [854.0, 854.0]
# id_22 585371 501629 float64 [10.0, 11.0] [44.0, 44.0]
# id_24 585793 501951 float64 [11.0, 10.0] [26.0, 26.0]
# id_25 585408 501652 float64 [100.0, 100.0] [548.0, 549.0]
# id_26 585377 501644 float64 [100.0, 100.0] [216.0, 216.0]
# id_32 512954 436020 float64 [0.0, 8.0] [32.0, 48.0]
# TransactionID 0.9999912302247972
# TransactionDT 0.9999912420706194
# D4 0.6235022749118371
# D10 0.6286918534353937
# D15 0.656386527558444
# V17 0.6043254778355056
# V18 0.6043360244840394
# V21 0.6024025459312126
# V22 0.6023967834911056
# V39 0.6042013522774983
# V40 0.6043679043842618
# V42 0.6027846850664762
# V43 0.602993160734882
# V59 0.6062431600304545
# V60 0.6062731792466197
# V63 0.6044405645401517
# V64 0.6046686648538365
# V71 0.601233607684024
# V72 0.6011519475112703
# V80 0.6140147827468387
# V81 0.6141781193113025
# V84 0.6122750944186358
# V85 0.6126906291516239
# V92 0.6079110495566917
# V93 0.6079951274433446
# id_13 0.6127490335663288
# id_31 0.6814965265192795
# id_02_to_std_card1 0.9708546040599491
# TransactionAmt_to_std_card1 0.6798867237187536
# R_emaildomain_bin 0.9969006409105138
# P_emaildomain_bin 0.975723397595431
# R_emaildomain_suffix 0.9164271543149654
# P_emaildomain_suffix 0.9310273453565542

# %%
print(df_train2.shape, df_test2.shape)
df_train2.columns.tolist()
# Out:
# (590540, 560) (506691, 559)
# ['TransactionID',
#  'isFraud',
#  'TransactionDT',
#  'TransactionAmt',
#  'ProductCD',
#  'card1',
#  'card2',
#  'card3',
#  'card4',
#  'card5',
#  'card6',
#  'addr1',
#  'addr2',
#  'dist1',
#  'dist2',
#  'P_emaildomain',
#  'R_emaildomain',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'C6',
#  'C7',
#  'C8',
#  'C9',
#  'C10',
#  'C11',
#  'C12',
#  'C13',
#  'C14',
#  'D1',
#  'D2',
#  'D3',
#  'D5',
#  'D6',
#  'D7',
#  'D8',
#  'D9',
#  'D11',
#  'D12',
#  'D13',
#  'D14',
#  'M1',
#  'M2',
#  'M3',
#  'M4',
#  'M5',
#  'M6',
#  'M7',
#  'M8',
#  'M9',
#  'V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'V11',
#  'V12',
#  'V13',
#  'V14',
#  'V15',
#  'V16',
#  'V19',
#  'V20',
#  'V23',
#  'V24',
#  'V25',
#  'V26',
#  'V27',
#  'V28',
#  'V29',
#  'V30',
#  'V31',
#  'V32',
#  'V33',
#  'V34',
#  'V35',
#  'V36',
#  'V37',
#  'V38',
#  'V41',
#  'V44',
#  'V45',
#  'V46',
#  'V47',
#  'V48',
#  'V49',
#  'V50',
#  'V51',
#  'V52',
#  'V53',
#  'V54',
#  'V55',
#  'V56',
#  'V57',
#  'V58',
#  'V61',
#  'V62',
#  'V65',
#  'V66',
#  'V67',
#  'V68',
#  'V69',
#  'V70',
#  'V73',
#  'V74',
#  'V75',
#  'V76',
#  'V77',
#  'V78',
#  'V79',
#  'V82',
#  'V83',
#  'V86',
#  'V87',
#  'V88',
#  'V89',
#  'V90',
#  'V91',
#  'V94',
#  'V95',
#  'V96',
#  'V97',
#  'V98',
#  'V99',
#  'V100',
#  'V101',
#  'V102',
#  'V103',
#  'V104',
#  'V105',
#  'V106',
#  'V107',
#  'V108',
#  'V109',
#  'V110',
#  'V111',
#  'V112',
#  'V113',
#  'V114',
#  'V115',
#  'V116',
#  'V117',
#  'V118',
#  'V119',
#  'V120',
#  'V121',
#  'V122',
#  'V123',
#  'V124',
#  'V125',
#  'V126',
#  'V127',
#  'V128',
#  'V129',
#  'V130',
#  'V131',
#  'V132',
#  'V133',
#  'V134',
#  'V135',
#  'V136',
#  'V137',
#  'V138',
#  'V139',
#  'V140',
#  'V141',
#  'V142',
#  'V143',
#  'V144',
#  'V145',
#  'V146',
#  'V147',
#  'V148',
#  'V149',
#  'V150',
#  'V151',
#  'V152',
#  'V153',
#  'V154',
#  'V155',
#  'V156',
#  'V157',
#  'V158',
#  'V159',
#  'V160',
#  'V161',
#  'V162',
#  'V163',
#  'V164',
#  'V165',
#  'V166',
#  'V167',
#  'V168',
#  'V169',
#  'V170',
#  'V171',
#  'V172',
#  'V173',
#  'V174',
#  'V175',
#  'V176',
#  'V177',
#  'V178',
#  'V179',
#  'V180',
#  'V181',
#  'V182',
#  'V183',
#  'V184',
#  'V185',
#  'V186',
#  'V187',
#  'V188',
#  'V189',
#  'V190',
#  'V191',
#  'V192',
#  'V193',
#  'V194',
#  'V195',
#  'V196',
#  'V197',
#  'V198',
#  'V199',
#  'V200',
#  'V201',
#  'V202',
#  'V203',
#  'V204',
#  'V205',
#  'V206',
#  'V207',
#  'V208',
#  'V209',
#  'V210',
#  'V211',
#  'V212',
#  'V213',
#  'V214',
#  'V215',
#  'V216',
#  'V217',
#  'V218',
#  'V219',
#  'V220',
#  'V221',
#  'V222',
#  'V223',
#  'V224',
#  'V225',
#  'V226',
#  'V227',
#  'V228',
#  'V229',
#  'V230',
#  'V231',
#  'V232',
#  'V233',
#  'V234',
#  'V235',
#  'V236',
#  'V237',
#  'V238',
#  'V239',
#  'V240',
#  'V241',
#  'V242',
#  'V243',
#  'V244',
#  'V245',
#  'V246',
#  'V247',
#  'V248',
#  'V249',
#  'V250',
#  'V251',
#  'V252',
#  'V253',
#  'V254',
#  'V255',
#  'V256',
#  'V257',
#  'V258',
#  'V259',
#  'V260',
#  'V261',
#  'V262',
#  'V263',
#  'V264',
#  'V265',
#  'V266',
#  'V267',
#  'V268',
#  'V269',
#  'V270',
#  'V271',
#  'V272',
#  'V273',
#  'V274',
#  'V275',
#  'V276',
#  'V277',
#  'V278',
#  'V279',
#  'V280',
#  'V281',
#  'V282',
#  'V283',
#  'V284',
#  'V285',
#  'V286',
#  'V287',
#  'V288',
#  'V289',
#  'V290',
#  'V291',
#  'V292',
#  'V293',
#  'V294',
#  'V295',
#  'V296',
#  'V297',
#  'V298',
#  'V299',
#  'V300',
#  'V301',
#  'V302',
#  'V303',
#  'V304',
#  'V305',
#  'V306',
#  'V307',
#  'V308',
#  'V309',
#  'V310',
#  'V311',
#  'V312',
#  'V313',
#  'V314',
#  'V315',
#  'V316',
#  'V317',
#  'V318',
#  'V319',
#  'V320',
#  'V321',
#  'V322',
#  'V323',
#  'V324',
#  'V325',
#  'V326',
#  'V327',
#  'V328',
#  'V329',
#  'V330',
#  'V331',
#  'V332',
#  'V333',
#  'V334',
#  'V335',
#  'V336',
#  'V337',
#  'V338',
#  'V339',
#  'id_01',
#  'id_02',
#  'id_03',
#  'id_04',
#  'id_05',
#  'id_06',
#  'id_07',
#  'id_08',
#  'id_09',
#  'id_10',
#  'id_11',
#  'id_12',
#  'id_14',
#  'id_15',
#  'id_16',
#  'id_17',
#  'id_18',
#  'id_19',
#  'id_20',
#  'id_21',
#  'id_22',
#  'id_23',
#  'id_24',
#  'id_25',
#  'id_26',
#  'id_27',
#  'id_28',
#  'id_29',
#  'id_30',
#  'id_32',
#  'id_33',
#  'id_34',
#  'id_35',
#  'id_36',
#  'id_37',
#  'id_38',
#  'DeviceType',
#  'DeviceInfo',
#  'P_emaildomain_prefix',
#  'card5_TransactionAmt_std',
#  'card1_fq_enc',
#  'DeviceInfo_version_fq_enc',
#  'id_30_fq_enc',
#  'card2_fq_enc',
#  'DeviceInfo_device_fq_enc',
#  'C10_fq_enc',
#  'uid_TransactionAmt_mean',
#  'C1_fq_enc',
#  'id_31_device_fq_enc',
#  'M_na',
#  'P_emaildomain_fq_enc',
#  'C6_fq_enc',
#  'id_33_fq_enc',
#  'D3_fq_enc',
#  'card2_TransactionAmt_std',
#  'id_30_device',
#  'uid2_TransactionAmt_std',
#  'C9_fq_enc',
#  'C5_fq_enc',
#  'card1_TransactionAmt_mean',
#  'C4_fq_enc',
#  'TransactionAmt_log1p',
#  'id_33_0',
#  'D7_fq_enc',
#  'M4_target_mean',
#  'id_31_device',
#  'card2_TransactionAmt_mean',
#  'id_30_device_fq_enc',
#  'TransactionAmt_check',
#  'D5_fq_enc',
#  'uid',
#  'DT_hour',
#  'addr1_fq_enc',
#  'C12_fq_enc',
#  'uid3_TransactionAmt_std',
#  'uid_TransactionAmt_std',
#  'email_check',
#  'uid2_TransactionAmt_mean',
#  'C8_fq_enc',
#  'R_emaildomain_fq_enc',
#  'DeviceInfo_device',
#  'dist2_fq_enc',
#  'C11_fq_enc',
#  'addr2_fq_enc',
#  'uid2',
#  'DT_day_week',
#  'M_sum',
#  'C14_fq_enc',
#  'C3_fq_enc',
#  'card1_TransactionAmt_std',
#  'uid_fq_enc',
#  'uid3',
#  'DeviceInfo_version',
#  'D8_fq_enc',
#  'D1_fq_enc',
#  'card3_TransactionAmt_mean',
#  'C7_fq_enc',
#  'card3_TransactionAmt_std',
#  'ProductCD_target_mean',
#  'id_33_1',
#  'DT_day',
#  'D6_fq_enc',
#  'DeviceInfo_fq_enc',
#  'R_emaildomain_prefix',
#  'D2_fq_enc',
#  'C13_fq_enc',
#  'card5_TransactionAmt_mean',
#  'C2_fq_enc',
#  'uid3_fq_enc',
#  'dist1_fq_enc',
#  'uid2_fq_enc',
#  'id_30_version',
#  'id_30_version_fq_enc',
#  'card3_fq_enc',
#  'card5_fq_enc',
#  'uid3_TransactionAmt_mean',
#  'TransactionAmt_to_mean_card1',
#  'first_value_addr1',
#  'PCA_D_1',
#  'PCA_C_0',
#  '_Minutes',
#  '_Days',
#  'PCA_D_2',
#  'PCA_C_2',
#  '_Weekdays',
#  'PCA_V_28',
#  'PCA_C_1',
#  'count_cluster',
#  'min_last',
#  'PCA_D_0',
#  'PCA_D_6',
#  'clusters_C',
#  'first_value_card1',
#  'std_last',
#  '_Second',
#  'PCA_D_4',
#  'PCA_D_3',
#  'TransactionAmt_to_std_card_id',
#  '_Hours',
#  'clusters_D',
#  'max_last',
#  'Card_ID',
#  'PCA_D_5',
#  'TransactionAmt_to_mean_card_id',
#  'mean_last',
#  'PCA_D_7',
#  'browser_id_31',
#  'id_36_count_full',
#  'device_version',
#  'id_02__D8',
#  'P_emaildomain__C2',
#  'id_02_to_std_addr1',
#  'card2__dist1',
#  'D15_to_std_card1',
#  'device_name',
#  'D15_to_mean_card1',
#  'card1__card5',
#  'id_02_to_mean_card1',
#  'Transaction_day_of_week',
#  'card6_count_full',
#  'card4_count_full',
#  'version_id_30',
#  'id_02_to_mean_card4',
#  'TransactionAmt_decimal',
#  'had_id',
#  'card2_count_full',
#  'card2__id_20',
#  'card3_count_full',
#  'screen_height',
#  'TransactionAmt_Log',
#  'id_02__id_20',
#  'D15_to_mean_addr1',
#  'DeviceInfo__P_emaildomain',
#  'card1_count_full',
#  'OS_id_30',
#  'id_02_to_std_card4',
#  'id_02_to_mean_addr1',
#  'card5__P_emaildomain',
#  'D15_to_std_addr1',
#  'screen_width',
#  'card5_count_full',
#  'addr1__card1',
#  'Transaction_hour',
#  'make_hour_feature',
#  'make_day_feature',
#  'P_emaildomain_1',
#  'P_emaildomain_2',
#  'R_emaildomain_1',
#  'R_emaildomain_2']

# %%
for col in df_train2.columns:
    if not ('int' in str(df_train2[col].dtype)) and (not 'float' in str(df_train2[col].dtype)):
        print(col, df_train2[col].dtype)

# %%
df_train2.to_pickle(f'{folder_path}/df_train2.gzde', compression='gzip')
df_test2.to_pickle(f'{folder_path}/df_test2.gzde', compression='gzip')
